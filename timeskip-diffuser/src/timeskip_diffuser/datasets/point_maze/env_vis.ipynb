# %%
from timeskip_diffuser.datasets.point_maze.open import OpenFlatDataset
from timeskip_diffuser.datasets.point_maze.umaze import UMazeFlatDataset
from timeskip_diffuser.datasets.point_maze.medium import MediumFlatDataset

# %%
open_dataset = OpenFlatDataset(horizon=160)
open_dataset.show_env(save_file="open.png")

# %%
umaze_dataset = UMazeFlatDataset(horizon=160)
umaze_dataset.show_env(save_file="umaze.png")

# %%
medium_dataset = MediumFlatDataset(horizon=160)
medium_dataset.show_env(save_file="medium.png")

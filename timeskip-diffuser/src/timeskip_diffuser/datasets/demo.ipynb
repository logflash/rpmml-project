# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from timeskip_diffuser.datasets.umaze_flat import UMazeFlatDataset
import random
import matplotlib.pyplot as plt

# %%
flat_dataset = UMazeFlatDataset(
    horizon=32
)

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']

# %%
traj_norm = random.choice(flat_dataset)
traj = flat_dataset.denormalize(traj_norm)
flat_dataset.visualize(traj)

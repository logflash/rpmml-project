# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from eqnet_independent_copy import EqNet, GaussianDiffusion, DiffuserTrainer, DiffuserPlanner, CompositeReward, expand_spline_from_skip_list, StartReachingReward, GoalReachingReward, SkipTotalTimeSkipPenalty, CurvaturePenalty, LogSkipReward
from point_maze_skip import MinariTrajectoryDatasetWithPseudoActions
import torch
from matplotlib.patches import Rectangle
import mujoco
from torch.utils.data import DataLoader, Dataset
from traj_verifiers.verifier import extract_wall_rects, verify_trajectory_dense, sample_free_point, endpoint_within_eps
from offlineskipdataset import OfflineSkipDataset
    




def run_planning_experiment_with_viz(
    planner,
    dataset_name,
    num_tasks=100,
    max_tries=10,
    horizon=32,
    seed=0,
    guidance_scale=1.0,
):
    rng = np.random.default_rng(seed)
    random.seed(seed)
    torch.manual_seed(seed)

    wall_rects = extract_wall_rects(dataset_name)

    # Hard-coded safe bounds for U-Maze
    bounds = (-1.4, 1.4, -1.4, 1.4)
    xmin, xmax, ymin, ymax = bounds

    successes = 0

    for task_id in range(num_tasks):
        print(f"\n=== Task {task_id + 1}/{num_tasks} ===")

        # --------------------------------------------------
        # Create a NEW figure per task  ← THIS IS CRITICAL
        # --------------------------------------------------
        fig, ax = plt.subplots(figsize=(8, 8))

        # Draw maze walls
        for wxmin, wxmax, wymin, wymax in wall_rects:
            ax.add_patch(
                Rectangle(
                    (wxmin, wymin),
                    wxmax - wxmin,
                    wymax - wymin,
                    color="black",
                    alpha=0.35,
                    zorder=0,
                )
            )

        ax.set_xlim(xmin, xmax)
        ax.set_ylim(ymin, ymax)
        ax.set_aspect("equal")

        # --------------------------------------------------
        # Sample start & goal
        # --------------------------------------------------
        start_xy = sample_free_point(wall_rects, rng, bounds)
        goal_xy  = sample_free_point(wall_rects, rng, bounds)

        current = np.array([start_xy[0], start_xy[1], 0.0, 0.0], dtype=np.float32)
        goal = goal_xy

        ax.scatter(*start_xy, marker="*", s=140, color="lime", zorder=5, label="Start")
        ax.scatter(*goal_xy,  marker="X", s=140, color="blue", zorder=5, label="Goal")

        reward_fn = CompositeReward(
            [
                StartReachingReward(start_xy, reward_scale=5.0),
                GoalReachingReward(goal, reward_scale=5.0),
                SkipTotalTimeSkipPenalty(reward_scale=0.03),
                CurvaturePenalty(reward_scale=0.05),
                LogSkipReward(reward_scale=0.0),
            ]
        )

        solved = False

        # --------------------------------------------------
        # Attempt loop — STOP AFTER FIRST SUCCESS
        # --------------------------------------------------
        for attempt in range(max_tries):
            traj = planner.plan_and_reconstruct(
                current,
                goal,
                reward_fn=reward_fn,
                horizon=horizon,
                guidance_scale=guidance_scale,
                condition_on_start=True,
                condition_on_goal=True,
                conditioning_schedule="constant",
                conditioning_strength=0.9,
                spline_func=expand_spline_from_skip_list,
            )

            pos_dense = traj["pos_dense"]
            feasible, coll_idx = verify_trajectory_dense(pos_dense, wall_rects) #no collision
            start_ok, goal_ok, start_err, goal_err = endpoint_within_eps(
                pos_dense,
                start_xy,
                goal_xy,
                0.05,
                0.05,
            ) #start,end is within reasonable dist of targets

            success = feasible and start_ok and goal_ok
            
            if success:
                ax.plot(
                    pos_dense[:, 0],
                    pos_dense[:, 1],
                    color="green",
                    linewidth=2.0,
                    alpha=0.8,
                    zorder=3,
                    label=f"Attempt {attempt + 1} (success)",
                )
                print(
                    f"  ✓ Attempt {attempt + 1} succeeded "
                    f"(start_err={start_err:.3f}, goal_err={goal_err:.3f})"
                )
                successes += 1
                solved = True
                break
            else:
                ax.plot(
                    pos_dense[:, 0],
                    pos_dense[:, 1],
                    color="red",
                    linewidth=1.0,
                    alpha=0.35,
                    zorder=2,
                )

                if not feasible:
                    cx, cy = pos_dense[coll_idx]
                    ax.scatter(cx, cy, s=70, marker="x", color="red", zorder=6)

                print(
                    f"  ✗ Attempt {attempt + 1} failed "
                    f"(collision={not feasible}, "
                    f"start_err={start_err:.3f}, goal_err={goal_err:.3f})"
                )

        # --------------------------------------------------
        # Task summary
        # --------------------------------------------------
        if solved:
            print("✓ Task solved")
        else:
            print("✗ Task failed (all attempts)")

        ax.set_title(
            f"Task {task_id + 1} — {'SUCCESS' if solved else 'FAIL'}"
        )
        ax.legend(loc="best")
        plt.show()   # ← GUARANTEED DRAW

    # --------------------------------------------------
    # Final summary
    # --------------------------------------------------
    print("\n==============================")
    print(f"Total tasks  : {num_tasks}")
    print(f"Max tries   : {max_tries}")
    print(f"Successes   : {successes}")
    print(f"Success rate: {successes / num_tasks:.3f}")
    print("==============================")

    return successes






device = "cuda" if torch.cuda.is_available() else "cpu"

#Load dataset that the model was trained on for denormalization statistics
OFFLINE_FILE = "/scratch/network/ts4953/dataset_gen/rpmml-project/timeskip-diffuser/src/timeskip_diffuser/datasets/fixed_offline_umaze_independent_skips_h32_mu1_sig1.npz"

dataset = OfflineSkipDataset(
    OFFLINE_FILE,
    horizon=32
)

#Load model + create planner
eqnet = EqNet(
        state_dim=dataset.traj_dim,
        hidden_dim=128,
        time_dim=32,
        n_layers=10, 
    )

diffusion = GaussianDiffusion(timesteps=200)
trainer = DiffuserTrainer(
        model = eqnet,
        diffusion = diffusion,
        dataset=dataset,
        device = device)
trainer.use_ema_for_inference()

trainer.load("/scratch/network/ts4953/dataset_gen/rpmml-project/timeskip-diffuser/src/timeskip_diffuser/diffuser/checkpoints/diffuser_fixed_h32_m1_s1_epoch_10.pt")
planner = DiffuserPlanner(eqnet, diffusion, dataset, device=device)

"""
run_planning_experiment(
    planner,
    dataset_name="D4RL/pointmaze/umaze-v2",
    num_tasks=50,
    max_tries=5,
    horizon=32,
    seed=42,
)
"""

run_planning_experiment_with_viz(
    planner,
    dataset_name="D4RL/pointmaze/umaze-v2",
    num_tasks=100,
    max_tries=10,
    horizon=32,
    seed=42,
)
# Out:
# Switched to EMA parameters for inference
#
# === Task 1/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.032, goal_err=0.002)
# ✓ Task solved
# === Task 2/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.044, goal_err=0.005)
# ✓ Task solved
# === Task 3/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.002, goal_err=0.001)
# ✓ Task solved
# === Task 4/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.026, goal_err=0.029)
# ✓ Task solved
# === Task 5/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.002, goal_err=0.029)
# ✓ Task solved
# === Task 6/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.006, goal_err=0.001)
# ✓ Task solved
# === Task 7/100 ===
#   ✗ Attempt 1 failed (collision=True, start_err=0.001, goal_err=0.057)
#   ✗ Attempt 2 failed (collision=True, start_err=0.001, goal_err=0.057)
#   ✗ Attempt 3 failed (collision=True, start_err=0.002, goal_err=0.054)
#   ✗ Attempt 4 failed (collision=False, start_err=0.001, goal_err=0.061)
#   ✗ Attempt 5 failed (collision=False, start_err=0.059, goal_err=0.000)
#   ✗ Attempt 6 failed (collision=True, start_err=0.045, goal_err=0.013)
#   ✗ Attempt 7 failed (collision=True, start_err=0.001, goal_err=0.059)
#   ✗ Attempt 8 failed (collision=True, start_err=0.001, goal_err=0.056)
#   ✗ Attempt 9 failed (collision=True, start_err=0.000, goal_err=0.054)
#   ✗ Attempt 10 failed (collision=True, start_err=0.004, goal_err=0.054)
# ✗ Task failed (all attempts)
# === Task 8/100 ===
#   ✗ Attempt 1 failed (collision=False, start_err=0.020, goal_err=0.054)
#   ✗ Attempt 2 failed (collision=True, start_err=0.005, goal_err=0.001)
#   ✗ Attempt 3 failed (collision=False, start_err=0.051, goal_err=0.014)
#   ✗ Attempt 4 failed (collision=True, start_err=0.056, goal_err=0.000)
#   ✓ Attempt 5 succeeded (start_err=0.010, goal_err=0.041)
# ✓ Task solved
# === Task 9/100 ===
#   ✗ Attempt 1 failed (collision=True, start_err=0.001, goal_err=0.025)
#   ✗ Attempt 2 failed (collision=True, start_err=0.005, goal_err=0.037)
#   ✗ Attempt 3 failed (collision=True, start_err=0.001, goal_err=0.012)
#   ✗ Attempt 4 failed (collision=True, start_err=0.021, goal_err=0.013)
#   ✗ Attempt 5 failed (collision=True, start_err=0.000, goal_err=0.053)
#   ✗ Attempt 6 failed (collision=True, start_err=0.004, goal_err=0.007)
#   ✗ Attempt 7 failed (collision=True, start_err=0.001, goal_err=0.031)
#   ✗ Attempt 8 failed (collision=True, start_err=0.001, goal_err=0.051)
#   ✗ Attempt 9 failed (collision=True, start_err=0.004, goal_err=0.022)
#   ✗ Attempt 10 failed (collision=True, start_err=0.000, goal_err=0.005)
# ✗ Task failed (all attempts)
# === Task 10/100 ===
#   ✗ Attempt 1 failed (collision=True, start_err=0.002, goal_err=0.044)
#   ✗ Attempt 2 failed (collision=True, start_err=0.023, goal_err=0.018)
#   ✗ Attempt 3 failed (collision=True, start_err=0.001, goal_err=0.053)
#   ✗ Attempt 4 failed (collision=True, start_err=0.000, goal_err=0.054)
#   ✗ Attempt 5 failed (collision=True, start_err=0.002, goal_err=0.052)
#   ✗ Attempt 6 failed (collision=True, start_err=0.001, goal_err=0.051)
#   ✗ Attempt 7 failed (collision=True, start_err=0.001, goal_err=0.024)
#   ✗ Attempt 8 failed (collision=True, start_err=0.001, goal_err=0.047)
#   ✗ Attempt 9 failed (collision=False, start_err=0.000, goal_err=0.061)
#   ✗ Attempt 10 failed (collision=True, start_err=0.001, goal_err=0.054)
# ✗ Task failed (all attempts)
# === Task 11/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.001, goal_err=0.029)
# ✓ Task solved
# === Task 12/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.009, goal_err=0.001)
# ✓ Task solved
# === Task 13/100 ===
#   ✗ Attempt 1 failed (collision=True, start_err=0.001, goal_err=0.054)
#   ✗ Attempt 2 failed (collision=False, start_err=0.010, goal_err=0.052)
#   ✗ Attempt 3 failed (collision=True, start_err=0.002, goal_err=0.057)
#   ✗ Attempt 4 failed (collision=False, start_err=0.050, goal_err=0.016)
#   ✗ Attempt 5 failed (collision=True, start_err=0.002, goal_err=0.006)
#   ✓ Attempt 6 succeeded (start_err=0.048, goal_err=0.001)
# ✓ Task solved
# === Task 14/100 ===
#   ✗ Attempt 1 failed (collision=False, start_err=0.054, goal_err=0.000)
#   ✗ Attempt 2 failed (collision=True, start_err=0.055, goal_err=0.001)
#   ✓ Attempt 3 succeeded (start_err=0.014, goal_err=0.004)
# ✓ Task solved
# === Task 15/100 ===
#   ✗ Attempt 1 failed (collision=True, start_err=0.023, goal_err=0.007)
#   ✗ Attempt 2 failed (collision=True, start_err=0.033, goal_err=0.004)
#   ✗ Attempt 3 failed (collision=True, start_err=0.042, goal_err=0.002)
#   ✗ Attempt 4 failed (collision=True, start_err=0.027, goal_err=0.001)
#   ✗ Attempt 5 failed (collision=True, start_err=0.050, goal_err=0.001)
#   ✗ Attempt 6 failed (collision=True, start_err=0.006, goal_err=0.002)
#   ✗ Attempt 7 failed (collision=True, start_err=0.049, goal_err=0.002)
#   ✗ Attempt 8 failed (collision=True, start_err=0.046, goal_err=0.000)
#   ✗ Attempt 9 failed (collision=True, start_err=0.057, goal_err=0.000)
#   ✗ Attempt 10 failed (collision=True, start_err=0.059, goal_err=0.002)
# ✗ Task failed (all attempts)
# === Task 16/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.021, goal_err=0.011)
# ✓ Task solved
# === Task 17/100 ===
#   ✗ Attempt 1 failed (collision=False, start_err=0.059, goal_err=0.000)
#   ✗ Attempt 2 failed (collision=True, start_err=0.002, goal_err=0.070)
#   ✗ Attempt 3 failed (collision=True, start_err=0.001, goal_err=0.055)
#   ✗ Attempt 4 failed (collision=False, start_err=0.059, goal_err=0.005)
#   ✗ Attempt 5 failed (collision=False, start_err=0.059, goal_err=0.001)
#   ✗ Attempt 6 failed (collision=True, start_err=0.001, goal_err=0.053)
#   ✗ Attempt 7 failed (collision=True, start_err=0.000, goal_err=0.042)
#   ✗ Attempt 8 failed (collision=True, start_err=0.001, goal_err=0.054)
#   ✗ Attempt 9 failed (collision=True, start_err=0.002, goal_err=0.046)
#   ✗ Attempt 10 failed (collision=True, start_err=0.003, goal_err=0.032)
# ✗ Task failed (all attempts)
# === Task 18/100 ===
#   ✗ Attempt 1 failed (collision=False, start_err=0.001, goal_err=0.060)
#   ✗ Attempt 2 failed (collision=True, start_err=0.017, goal_err=0.012)
#   ✓ Attempt 3 succeeded (start_err=0.039, goal_err=0.040)
# ✓ Task solved
# === Task 19/100 ===
#   ✗ Attempt 1 failed (collision=False, start_err=0.000, goal_err=0.053)
#   ✗ Attempt 2 failed (collision=False, start_err=0.000, goal_err=0.055)
#   ✗ Attempt 3 failed (collision=False, start_err=0.002, goal_err=0.056)
#   ✗ Attempt 4 failed (collision=False, start_err=0.002, goal_err=0.054)
#   ✗ Attempt 5 failed (collision=False, start_err=0.001, goal_err=0.056)
#   ✗ Attempt 6 failed (collision=False, start_err=0.058, goal_err=0.002)
#   ✗ Attempt 7 failed (collision=False, start_err=0.001, goal_err=0.052)
#   ✗ Attempt 8 failed (collision=False, start_err=0.058, goal_err=0.011)
#   ✗ Attempt 9 failed (collision=False, start_err=0.005, goal_err=0.057)
#   ✓ Attempt 10 succeeded (start_err=0.002, goal_err=0.012)
# ✓ Task solved
# === Task 20/100 ===
#   ✗ Attempt 1 failed (collision=True, start_err=0.003, goal_err=0.041)
#   ✗ Attempt 2 failed (collision=True, start_err=0.002, goal_err=0.054)
#   ✗ Attempt 3 failed (collision=True, start_err=0.000, goal_err=0.053)
#   ✗ Attempt 4 failed (collision=True, start_err=0.001, goal_err=0.051)
#   ✗ Attempt 5 failed (collision=True, start_err=0.001, goal_err=0.055)
#   ✗ Attempt 6 failed (collision=True, start_err=0.002, goal_err=0.052)
#   ✗ Attempt 7 failed (collision=True, start_err=0.006, goal_err=0.034)
#   ✗ Attempt 8 failed (collision=True, start_err=0.000, goal_err=0.055)
#   ✗ Attempt 9 failed (collision=True, start_err=0.001, goal_err=0.048)
#   ✗ Attempt 10 failed (collision=True, start_err=0.001, goal_err=0.055)
# ✗ Task failed (all attempts)
# === Task 21/100 ===
#   ✗ Attempt 1 failed (collision=True, start_err=0.013, goal_err=0.005)
#   ✓ Attempt 2 succeeded (start_err=0.038, goal_err=0.016)
# ✓ Task solved
# === Task 22/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.002, goal_err=0.005)
# ✓ Task solved
# === Task 23/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.048, goal_err=0.002)
# ✓ Task solved
# === Task 24/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.047, goal_err=0.009)
# ✓ Task solved
# === Task 25/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.042, goal_err=0.014)
# ✓ Task solved
# === Task 26/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.009, goal_err=0.048)
# ✓ Task solved
# === Task 27/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.003, goal_err=0.029)
# ✓ Task solved
# === Task 28/100 ===
#   ✗ Attempt 1 failed (collision=False, start_err=0.055, goal_err=0.013)
#   ✗ Attempt 2 failed (collision=True, start_err=0.055, goal_err=0.006)
#   ✗ Attempt 3 failed (collision=True, start_err=0.012, goal_err=0.011)
#   ✗ Attempt 4 failed (collision=True, start_err=0.058, goal_err=0.001)
#   ✗ Attempt 5 failed (collision=True, start_err=0.053, goal_err=0.004)
#   ✗ Attempt 6 failed (collision=True, start_err=0.003, goal_err=0.049)
#   ✗ Attempt 7 failed (collision=True, start_err=0.059, goal_err=0.001)
#   ✗ Attempt 8 failed (collision=True, start_err=0.005, goal_err=0.017)
#   ✗ Attempt 9 failed (collision=False, start_err=0.060, goal_err=0.000)
#   ✗ Attempt 10 failed (collision=True, start_err=0.008, goal_err=0.005)
# ✗ Task failed (all attempts)
# === Task 29/100 ===
#   ✓ Attempt 1 succeeded (start_err=0.014, goal_err=0.037)
# ✓ Task solved
# === Task 30/100 ===
#   ✗ Attempt 1 failed (collision=True, start_err=0.001, goal_err=0.006)
#   ✗ Attempt 2 failed (collision=False, start_err=0.060, goal_err=0.003)
#   ✗ Attempt 3 failed (collision=True, start_err=0.019, goal_err=0.001)
#   ✗ Attempt 4 failed (collision=True, start_err=0.001, goal_err=0.004)
#   ✗ Attempt 5 failed (collision=True, start_err=0.059, goal_err=0.001)
#   ✗ Attempt 6 failed (collision=True, start_err=0.002, goal_err=0.007)
#   ✗ Attempt 7 failed (collision=True, start_err=0.004, goal_err=0.023)
#   ✗ Attempt 8 failed (collision=True, start_err=0.014, goal_err=0.021)

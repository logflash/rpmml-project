# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from eqnet_independent_copy import EqNet, GaussianDiffusion, DiffuserTrainer, DiffuserPlanner, CompositeReward, GoalReachingReward, PathLengthPenalty, StartReachingReward
from point_maze_4 import MinariTrajectoryDataset
import torch
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 4
#       2 import numpy as np
#       3 import random
# ----> 4 from eqnet_independent_copy import EqNet, GaussianDiffusion, DiffuserTrainer, DiffuserPlanner, CompositeReward, GoalReachingReward, PathLengthPenalty, StartReachingReward
#       5 from point_maze_4 import MinariTrajectoryDataset
#       6 import torch
#
# ImportError: cannot import name 'PathLengthPenalty' from 'eqnet_independent_copy' (/scratch/network/ts4953/dataset_gen/rpmml-project/timeskip-diffuser/src/timeskip_diffuser/pointmaze/eqnet_independent_copy.py)

# %%
dataset = MinariTrajectoryDataset(
    dataset_name="D4RL/pointmaze/umaze-v2",
    horizon=160
)

# %%
env = dataset.dataset.recover_environment()

def unwrap_env(env):
    while hasattr(env, "env"):
        env = env.env
    return env

env = unwrap_env(env)

mj_model = env.model
mj_data = env.data

# %%
len(dataset)
# Out:
# 8594

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

model = EqNet(
    state_dim=dataset.state_dim,
    hidden_dim=128,
    time_dim=32,
)
diffusion = GaussianDiffusion(timesteps=200)
trainer = DiffuserTrainer(model, diffusion, dataset, lr=1e-4, device=device)
trainer.load("checkpoints/diffuser_flat_eqnet_independent_epoch_39.pt")
planner = DiffuserPlanner(model, diffusion, dataset, device=device)
# Out:
# Using device: cuda

# %%
from matplotlib.patches import Rectangle
import mujoco

# %%
print(len(dataset))
# Out:
# 8594

# %%
# Sample a trajectory window
# 32 - 325277
# 64 - 94808,187934,221081
idx = random.randint(0, len(dataset) - 1)
traj_norm = dataset[idx]
traj = dataset.denormalize(traj_norm).numpy()
xy = traj[:, :2]           # XY coordinates (i.e., flat outputs)

# Plot the trajectory
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(xy[:, 0], xy[:, 1], marker='o', linewidth=0, markersize=1, label='Trajectory')
ax.scatter(xy[0, 0], xy[0, 1], c='lime', s=120, label='Start')
ax.scatter(xy[-1, 0], xy[-1, 1], c='red', s=120, label='End')

# Render MuJoCo walls
for geom_id in range(mj_model.ngeom):

    # Get geom name
    name = mujoco.mj_id2name(mj_model, mujoco.mjtObj.mjOBJ_GEOM, geom_id)

    if name is None or not "block" in name:
        continue

    pos = mj_model.geom_pos[geom_id]     # center (x, y, z)
    size = mj_model.geom_size[geom_id]   # half-extents (hx, hy, hz)

    cx, cy = pos[:2]
    hx, hy = size[:2]

    rect = Rectangle(
        (cx - hx, cy - hy),
        2 * hx,
        2 * hy,
        color="black",
        alpha=0.35,
        zorder=0
    )
    ax.add_patch(rect)

# Final figure styling
ax.set_title("PointMaze Trajectory")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.axis("equal")
ax.grid(True)
ax.legend()
plt.xlim(-2.5, +2.5)
plt.ylim(-2.5, +2.5)

# plt.show()
plt.savefig("trajectory.png")

# %%
idx
# Out:
# 4251

# %%
current = traj[0].copy()
# current[0] -= 0.2
# current[1] += 0.1
goal = traj[-1].copy()

# %%
print(current, goal)
# Out:
# [-1.0518014  -1.09712115] [-0.47055732  0.94878036]

# %%
reward_fn = CompositeReward([
    StartReachingReward(current[:2], reward_scale=5.0),  # Increased from 10
    GoalReachingReward(goal, reward_scale=5.0),          # Keep balanced
    PathLengthPenalty(reward_scale=0.23),                  # Reduced from 0.5!
])

traj_model = planner.plan(
    current, goal,
    horizon=160,
    reward_fn=reward_fn,
    guidance_scale=1.0,
    condition_on_start=True,
    condition_on_goal=True,
    conditioning_schedule="constant",
    conditioning_strength=1.0,
)
print(f"Start (actual): {traj_model[0, :2]}")
print(f"Start (target): {current[:2]}")
print(f"Start error: {np.linalg.norm(traj_model[0, :2] - current[:2]):.4f}")
print(f"End: {traj_model[-1, :2]}")
print(f"Goal: {goal}")
print(f"Goal error: {np.linalg.norm(traj_model[-1, :2] - goal):.4f}")

# Check for discontinuities (physics violations)
diffs = np.linalg.norm(traj_model[1:, :2] - traj_model[:-1, :2], axis=1)
max_jump = diffs.max()
print(f"Max step size: {max_jump:.4f}")
if max_jump > 0.2:  # Adjust threshold based on your maze
    print("  ⚠️  WARNING: Large discontinuity detected!")
else:
    print("  ✓ Trajectory appears continuous")
# Out:
# Start (actual): [-1.05155962 -1.09694412]
# Start (target): [-1.0518014  -1.09712115]
# Start error: 0.0003
# End: [-0.47041197  0.94861792]
# Goal: [-0.47055732  0.94878036]
# Goal error: 0.0002
# Max step size: 0.1007
#   ✓ Trajectory appears continuous

# %%
traj_model.shape
# Out:
# (160, 2)

# %%
xy_model = traj_model[:, :2]           # XY coordinates (i.e., flat outputs)

# Plot the trajectory
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(xy_model[:, 0], xy_model[:, 1], marker='o', linewidth=0.5, markersize=1, label='Trajectory')
ax.scatter(current[0], current[1], c='lime', s=120, label='Start')
ax.scatter(goal[0], goal[1], c='red', s=120, label='End')

# Render MuJoCo walls
for geom_id in range(mj_model.ngeom):

    # Get geom name
    name = mujoco.mj_id2name(mj_model, mujoco.mjtObj.mjOBJ_GEOM, geom_id)

    if name is None or not "block" in name:
        continue

    pos = mj_model.geom_pos[geom_id]     # center (x, y, z)
    size = mj_model.geom_size[geom_id]   # half-extents (hx, hy, hz)

    cx, cy = pos[:2]
    hx, hy = size[:2]

    rect = Rectangle(
        (cx - hx, cy - hy),
        2 * hx,
        2 * hy,
        color="black",
        alpha=0.35,
        zorder=0
    )
    ax.add_patch(rect)

# Final figure styling
ax.set_title("PointMaze Trajectory")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.axis("equal")
ax.grid(True)
ax.legend()
plt.xlim(-2.5, +2.5)
plt.ylim(-2.5, +2.5)

# plt.show()
plt.savefig("trajectory.png")

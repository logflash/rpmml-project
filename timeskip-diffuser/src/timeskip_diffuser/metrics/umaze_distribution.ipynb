# %%
import sys, os

# Path to your project root (the folder that contains pointmaze/, rpmml_project/, etc.)
PROJECT_ROOT = "/scratch/network/dd6849/rpmml-project/timeskip-diffuser/src/timeskip_diffuser"

if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

print("PYTHONPATH updated with:", PROJECT_ROOT)
# Out:
# PYTHONPATH updated with: /scratch/network/dd6849/rpmml-project/timeskip-diffuser/src/timeskip_diffuser

# %%
from umaze_distribution_snoop import *
from datasets.umaze_flat import UMazeFlatDataset

# %%
dataset = UMazeFlatDataset()

# %%
rate, count, total = compute_u_completion_rate(dataset)
print(f"U-completion rate: {rate:.4f} ({count}/{total})")
# Out:
# U-completion rate (both directions): 0.0234  (309/13210)
# U-completion rate: 0.0234 (309/13210)

# %%
visualize_u_trajectories(dataset, allow_reverse=True)

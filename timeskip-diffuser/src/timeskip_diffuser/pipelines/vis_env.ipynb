# %%
from timeskip_diffuser.datasets.point_maze.umaze import UMazeFlatDataset
from timeskip_diffuser.datasets.point_maze.medium import MediumFlatDataset
from timeskip_diffuser.datasets.point_maze.open import OpenFlatDataset

maze = OpenFlatDataset()
maze.visualize(None)
# Out:
# /scratch/network/ts4953/recloned/rpmml-project/timeskip-diffuser/src/timeskip_diffuser/datasets/point_maze/open.py:182: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc="upper right", fontsize=10)
